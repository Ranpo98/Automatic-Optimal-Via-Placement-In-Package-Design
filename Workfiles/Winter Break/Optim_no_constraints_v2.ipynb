# %%
from scipy import optimize
from numpy import arange
from numpy import meshgrid
from numpy.random import random as rand
from matplotlib import pyplot as plt
from itertools import product
from mpl_toolkits.mplot3d import Axes3D
import autograd.numpy as np
from autograd import grad, jacobian

# objective function
# def func(x,y):
#     return x**2.0 + y**2.0
def func(x):
    return x[0] ** 2 + x[1] ** 2 

# define range for input
r_min, r_max = -5.0, 5.0
# sample input range for x and y 
xaxis = np.linspace(-5,5,201)
yaxis = np.linspace(-5,5,201)
# create a meshgrid
x = meshgrid(xaxis, yaxis)
# compute function
results = func(x)
# print("x0 = ",x[0],"\n")
# print("x1 =", x[1],"\n")
# print("results =",results,"\n") 
# create a surface plot
figure = plt.figure()
ax = plt.figure().add_subplot(projection = "3d")
ax.plot_surface(x[0],x[1], results, cmap='Spectral')
# show the plot 
plt.show()

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
result = optimize.minimize(func, point, method='Nelder-Mead')     
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_NM = result['x']
# print("xf_func =",xf_func_NM)
func_val_NM = func(xf_func_NM)
print('xf_func: f(%s) = %.5f' % (xf_func_NM, func_val_NM))
print("func_val = ",func(xf_func_NM))     


# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_NM[0],xf_func_NM[1], func_val_NM,color='green')
# show the plot 
plt.show()
# Out:
# point =  [-3.29969328 -1.09758259]
# Status : Optimization terminated successfully.
# Iteration: 88
# xf_func: f([ 2.24677091e-05 -2.94675114e-05]) = 0.00000
# func_val =  1.3731321769127022e-09

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
result = optimize.minimize(func, point, method='BFGS')     
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_BFGS = result['x']
func_val_BFGS = func(xf_func_BFGS)
print('xf_func: f(%s) = %.5f' % (xf_func_BFGS, func_val_BFGS))
print("func_val = ",func(xf_func_BFGS))     
# plt.plot(solution, objective(solution), "o")

# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_BFGS[0],xf_func_BFGS[1], func_val_BFGS,color='red')
# show the plot 
plt.show()
# Out:
# point =  [-3.63211987  0.11761023]
# Status : Optimization terminated successfully.
# Iteration: 12
# xf_func: f([-1.83103606e-08 -3.02382260e-07]) = 0.00000
# func_val =  9.17703002211979e-14

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
result = optimize.minimize(func, point, method='CG')     
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_CG = result['x']
func_val_CG = func(xf_func_CG)
print('xf_func: f(%s) = %.5f' % (xf_func_CG, func_val_CG))
print("func_val = ",func(xf_func_CG))     
# plt.plot(solution, objective(solution), "o")

# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_CG[0],xf_func_CG[1], func_val_CG,color='blue')
# show the plot 
plt.show()
# Out:
# point =  [-1.74419337 -1.78813522]
# Status : Optimization terminated successfully.
# Iteration: 9
# xf_func: f([-4.46457618e-08 -4.36548928e-08]) = 0.00000
# func_val =  3.89899370902242e-15

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
# jac = 2 * x[0] + 2 * x[1]     
jac = jacobian(func)
result = optimize.minimize(func, point, method='Newton-CG',jac=jac)         
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_Newton_CG = result['x'] 
func_val_Newton_CG = func(xf_func_Newton_CG)
print('xf_func: f(%s) = %.5f' % (xf_func_Newton_CG, func_val_Newton_CG))
print("func_val = ",func(xf_func_Newton_CG))     
# plt.plot(solution, objective(solution), "o")

# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_Newton_CG[0],xf_func_Newton_CG[1], func_val_Newton_CG,color='orange')
# show the plot 
plt.show()
# Out:
# point =  [-4.83730625  3.56236414]
# Status : Optimization terminated successfully.
# Iteration: 3
# xf_func: f([-3.59225627e-09  2.64546518e-09]) = 0.00000
# func_val =  1.9902791130883855e-17

# %%
# plot combined
plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')     
ax.set_ylabel('Y')
ax.set_zlabel('Z')


ax.plot_surface(x[0],x[1], results, cmap='Spectral')
ax.scatter(xf_func_NM[0],xf_func_NM[1], func_val_NM,color='green')
ax.scatter(xf_func_BFGS[0],xf_func_BFGS[1], func_val_BFGS,color='red')
ax.scatter(xf_func_CG[0],xf_func_CG[1], func_val_CG,color='blue')
ax.scatter(xf_func_Newton_CG[0],xf_func_Newton_CG[1], func_val_Newton_CG,color='orange')

plt.show()
