# %%
from scipy import optimize
from numpy import arange
from numpy import meshgrid
from numpy.random import random as rand
from matplotlib import pyplot as plt
from itertools import product
from mpl_toolkits.mplot3d import Axes3D
import autograd.numpy as np
from autograd import grad, jacobian

# objective function
# def func(x,y):
#     return x**2.0 + y**2.0
def func(x):
    return x[0] ** 2 + x[1] ** 2 

# define range for input
r_min, r_max = -5.0, 5.0
# sample input range for x and y 
xaxis = np.linspace(-5,5,201)
yaxis = np.linspace(-5,5,201)
# create a meshgrid
x = meshgrid(xaxis, yaxis)
# compute function
results = func(x)
# print("x0 = ",x[0],"\n")
# print("x1 =", x[1],"\n")
# print("results =",results,"\n") 
# create a surface plot
figure = pyplot.figure()
ax = plt.figure().add_subplot(projection = "3d")
ax.plot_surface(x[0],x[1], results, cmap='Spectral')
# show the plot 
pyplot.show()

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
result = optimize.minimize(func, point, method='Nelder-Mead')     
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_NM = result['x']
# print("xf_func =",xf_func_NM)
func_val_NM = func(xf_func_NM)
print('xf_func: f(%s) = %.5f' % (xf_func_NM, func_val_NM))
print("func_val = ",func(xf_func_NM))     


# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_NM[0],xf_func_NM[1], func_val_NM,color='green')
# show the plot 
pyplot.show()
# Out:
# point =  [-1.6139111   1.12944159]
# Status : Optimization terminated successfully.
# Iteration: 88
# xf_func: f([2.47611945e-05 1.35771448e-05]) = 0.00000
# func_val =  7.974556115164078e-10

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
result = optimize.minimize(func, point, method='BFGS')     
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_BFGS = result['x']
func_val_BFGS = func(xf_func_BFGS)
print('xf_func: f(%s) = %.5f' % (xf_func_BFGS, func_val_BFGS))
print("func_val = ",func(xf_func_BFGS))     
# plt.plot(solution, objective(solution), "o")

# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_BFGS[0],xf_func_BFGS[1], func_val_BFGS,color='red')
# show the plot 
pyplot.show()
# Out:
# point =  [-1.48724931 -4.20730072]
# Status : Optimization terminated successfully.
# Iteration: 12
# xf_func: f([-5.96424331e-07  2.38488336e-07]) = 0.00000
# func_val =  4.1259866857902314e-13

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
result = optimize.minimize(func, point, method='CG')     
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_CG = result['x']
func_val_CG = func(xf_func_CG)
print('xf_func: f(%s) = %.5f' % (xf_func_CG, func_val_CG))
print("func_val = ",func(xf_func_CG))     
# plt.plot(solution, objective(solution), "o")

# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_CG[0],xf_func_CG[1], func_val_CG,color='blue')
# show the plot 
pyplot.show()
# Out:
# point =  [-4.76203607  2.46169066]
# Status : Optimization terminated successfully.
# Iteration: 21
# xf_func: f([-7.4505806e-09 -7.4505806e-09]) = 0.00000
# func_val =  1.1102230246251565e-16

# %%
# define input range
r_min, r_max = -5.0, 5.0
# define the starting point in the domain
point = r_min + rand(2) * (r_max - r_min)
print("point = ", point) 
# search for the minimization 
# jac = 2 * x[0] + 2 * x[1]     
jac = jacobian(func)
result = optimize.minimize(func, point, method='Newton-CG',jac=jac)         
# print the results (successful / iteration)     
print('Status : %s' % result['message'])
print('Iteration: %d' % result['nfev'])
# evaluate solution
xf_func_Newton_CG = result['x'] 
func_val_Newton_CG = func(xf_func)
print('xf_func: f(%s) = %.5f' % (xf_func_Newton_CG, func_val_Newton_CG))
print("func_val = ",func(xf_func_Newton_CG))     
# plt.plot(solution, objective(solution), "o")

# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(xf_func_Newton_CG[0],xf_func_Newton_CG[1], func_val_Newton_CG,color='orange')
# show the plot 
pyplot.show()
# Out:
# point =  [-2.24596307 -0.14158175]
# Status : Optimization terminated successfully.
# Iteration: 3
# xf_func: f([2.50930388e-09 1.58182301e-10]) = 0.00000
# func_val =  6.321627581311668e-18

# %%
# plot combined
plt.figure()
ax = pyplot.axes(projection='3d')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('X')     
ax.set_ylabel('Y')
ax.set_zlabel('Z')


ax.plot_surface(x[0],x[1], results, cmap='Spectral')
ax.scatter(xf_func_NM[0],xf_func_NM[1], func_val_NM,color='green')
ax.scatter(xf_func_BFGS[0],xf_func_BFGS[1], func_val_BFGS,color='red')
ax.scatter(xf_func_CG[0],xf_func_CG[1], func_val_CG,color='blue')
ax.scatter(xf_func_Newton_CG[0],xf_func_Newton_CG[1], func_val_Newton_CG,color='orange')

pyplot.show()

# %%
ax.viewangle
