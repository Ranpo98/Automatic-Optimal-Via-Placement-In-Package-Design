# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

def parabolic(x):
    return x**2 + 10

def sine(x):
    return np.sin(x)

def inverse(x):
    return 1/x

def mos(x):
    return 2**x + np.sin(x)

def exp(x):
    return x**2 + np.sin(x)

from scipy import optimize

def callback(x):
    history.append(x)
    
# The default (Nelder Mead)
flist = [parabolic, sine, inverse, mos, exp]  
optimizer_list = ['Nelder-Mead','BFGS','CG']
x0_option = [0,3]

progress = []
for f,m,o in product(flist,optimizer_list,x0_option): 
    history = []
    print(f,m,o)
    result = optimize.minimize(f,x0 = o, method = m, tol=1e-9,callback = callback)
    xf = result["x"]
    callback(xf)
    progress.append(history)

print(len(progress))
# print(len(progress[0]))
# print(len(progress[1]))
# print(len(progress[2]))
# print(len(progress[3]))

x = np.arange(len(progress[0]))
x1 = np.arange(len(progress[1]))
x2 = np.arange(len(progress[2]))
x3 = np.arange(len(progress[3]))
x4 = np.arange(len(progress[4]))
x5 = np.arange(len(progress[5]))
x6 = np.arange(len(progress[6]))
x7 = np.arange(len(progress[7]))
x8 = np.arange(len(progress[8]))
x9 = np.arange(len(progress[9]))
x10 = np.arange(len(progress[10]))
x11 = np.arange(len(progress[11]))
x12 = np.arange(len(progress[12]))
x13 = np.arange(len(progress[13]))
x14 = np.arange(len(progress[14]))
x15 = np.arange(len(progress[15]))
x16 = np.arange(len(progress[16]))
x17 = np.arange(len(progress[17]))
x18 = np.arange(len(progress[18]))
x19 = np.arange(len(progress[19]))
x20 = np.arange(len(progress[20]))
x21 = np.arange(len(progress[21]))
x22 = np.arange(len(progress[22]))
x23 = np.arange(len(progress[23]))
x24 = np.arange(len(progress[24]))
x25 = np.arange(len(progress[25]))
x26 = np.arange(len(progress[26]))
x27 = np.arange(len(progress[27]))
x28 = np.arange(len(progress[28]))
x29 = np.arange(len(progress[29]))


plt.subplots_adjust(left= 10, right= 15, bottom= 5, top= 6, wspace= 0.0002, hspace= 0.0001)


plt.subplot(5,2,1)
plt.title("Parabolic(x0 = 0)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x,progress[0], label = "Nerlder-Mead")
plt.plot(x2,progress[2], label = "BFGS")
plt.plot(x4,progress[4], label = "CG ")
# plt.plot(x3,progress[3], label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,3)
plt.title("Parabolic(x0 = 3)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x1,progress[1], label = "Nerlder-Mead")
plt.plot(x3,progress[3], label = "BFGS")
plt.plot(x5,progress[5], label = "CG ")
# plt.plot(x3,progress[3], label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,3)
plt.title("Sine(x0 = 0)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x6,progress[6],label = "Nerlder-Mead")
plt.plot(x8,progress[8],label = "BFGS")
plt.plot(x10,progress[10],label = "CG")
# plt.plot(x7,progress[7],label = "Powell")
plt.tight_layout() 
plt.legend() 

plt.subplot(5,2,4)
plt.title("Sine(x0 = 3)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x7,progress[7],label = "Nerlder-Mead")
plt.plot(x9,progress[9],label = "BFGS")
plt.plot(x11,progress[11],label = "CG")
# plt.plot(x7,progress[7],label = "Powell")
plt.tight_layout() 
plt.legend() 

plt.subplot(5,2,5)
plt.title("Inverse(x0 = 0)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x12,progress[12],label = "Nerlder-Mead")
plt.plot(x14,progress[14],label = "BFGS")
plt.plot(x16,progress[16],label = "CG")
# plt.plot(x11,progress[11],label = "BFGS")
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,6)
plt.title("Inverse(x0 = 3)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x13,progress[13],label = "Nerlder-Mead")
plt.plot(x15,progress[15],label = "BFGS")
plt.plot(x17,progress[17],label = "CG")
# plt.plot(x11,progress[11],label = "BFGS")
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,7)
plt.title("Mos(x0 = 0)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x18,progress[18],label = "Nerlder-Mead")
plt.plot(x20,progress[20],label = "BFGS")
plt.plot(x22,progress[22],label = "CG")
# plt.plot(x15,progress[15],label = "Powell")       
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,8)
plt.title("Mos(x0 = 3)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x19,progress[19],label = "Nerlder-Mead")
plt.plot(x21,progress[21],label = "BFGS")
plt.plot(x23,progress[23],label = "CG")
# plt.plot(x15,progress[15],label = "Powell")       
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,9)
plt.title("Exp(x0 = 0)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x24,progress[24],label = "Nerlder-Mead")
plt.plot(x26,progress[26],label = "BFGS")
plt.plot(x28,progress[28],label = "CG")
# plt.plot(x19,progress[19],label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(5,2,10)
plt.title("Exp(x0 = 3)")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x25,progress[25],label = "Nerlder-Mead")
plt.plot(x27,progress[27],label = "BFGS")
plt.plot(x29,progress[29],label = "CG")
# plt.plot(x19,progress[19],label = "Powell")
plt.tight_layout()
plt.legend() 

plt.show()
# Out:
# <function parabolic at 0x000001487FF82DC8> Nelder-Mead 0
# <function parabolic at 0x000001487FF82DC8> Nelder-Mead 3
# <function parabolic at 0x000001487FF82DC8> BFGS 0
# <function parabolic at 0x000001487FF82DC8> BFGS 3
# <function parabolic at 0x000001487FF82DC8> CG 0
# <function parabolic at 0x000001487FF82DC8> CG 3
# <function sine at 0x00000148059A8F78> Nelder-Mead 0
# <function sine at 0x00000148059A8F78> Nelder-Mead 3
# <function sine at 0x00000148059A8F78> BFGS 0
# <function sine at 0x00000148059A8F78> BFGS 3
# <function sine at 0x00000148059A8F78> CG 0
# <function sine at 0x00000148059A8F78> CG 3
# <function inverse at 0x0000014805A11048> Nelder-Mead 0
# <function inverse at 0x0000014805A11048> Nelder-Mead 3
# <function inverse at 0x0000014805A11048> BFGS 0
# <function inverse at 0x0000014805A11048> BFGS 3
# <function inverse at 0x0000014805A11048> CG 0
# <function inverse at 0x0000014805A11048> CG 3
# <function mos at 0x0000014805A110D8> Nelder-Mead 0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

def parabolic(x):
    return x**2 + 10

def sine(x):
    return np.sin(x)

def inverse(x):
    return 1/x

def mos(x):
    return 2**x + np.sin(x)

def exp(x):
    return x**2 + np.sin(x)

from scipy import optimize

def callback(x):
    history.append(x)
    
# The default (Nelder Mead)
optimizer_list = ['Nelder-Mead','BFGS','CG','Powell']
flist = [parabolic, sine, inverse,mos, exp]     
progress = []
for m,f in product(optimizer_list,flist): 
    history = []
#     print(m,f)
#     if (m = 'Newton-CG'):
#         J = 
    result = optimize.minimize(f,x0 = 3, method = m, tol=1e-9,callback = callback)
    xf = result["x"]
    callback(xf)
    progress.append(history)
#     print(*progress,sep = "\n")
# print(len(progress))
# print(len(progress[0]))
# print(len(progress[1]))
# print(len(progress[2]))
# print(len(progress[3]))

x = np.arange(len(progress[0]))
x1 = np.arange(len(progress[1]))
x2 = np.arange(len(progress[2]))
x3 = np.arange(len(progress[3]))
x4 = np.arange(len(progress[4]))
x5 = np.arange(len(progress[5]))
x6 = np.arange(len(progress[6]))
x7 = np.arange(len(progress[7]))
x8 = np.arange(len(progress[8]))
x9 = np.arange(len(progress[9]))
x10 = np.arange(len(progress[10]))
x11 = np.arange(len(progress[11]))
x12 = np.arange(len(progress[12]))
x13 = np.arange(len(progress[13]))
x14 = np.arange(len(progress[14]))
x15 = np.arange(len(progress[15]))
x16 = np.arange(len(progress[16]))
x17 = np.arange(len(progress[17]))
x18 = np.arange(len(progress[18]))
x19 = np.arange(len(progress[19]))


plt.subplots_adjust(left= 0.25, right= 1.8, bottom= 0.2, top= 1.8, wspace= 1, hspace= 1)


plt.subplot(3,2,1)
plt.title("Parabolic")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x,progress[0], label = "Nerlder-Mead")
plt.plot(x1,progress[1], label = "BFGS")
plt.plot(x2,progress[2], label = "CG ")
plt.plot(x3,progress[3], label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(3,2,2)
plt.title("Sine")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x4,progress[4],label = "Nerlder-Mead")
plt.plot(x5,progress[5],label = "BFGS")
plt.plot(x6,progress[6],label = "CG")
plt.plot(x7,progress[7],label = "Powell")
plt.tight_layout() 
plt.legend() 

plt.subplot(3,2,3)
plt.title("Inverse")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x8,progress[8],label = "Nerlder-Mead")
plt.plot(x9,progress[9],label = "BFGS")
plt.plot(x10,progress[10],label = "CG")
plt.plot(x11,progress[11],label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(3,2,4)
plt.title("Mos")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x12,progress[12],label = "Nerlder-Mead")
plt.plot(x13,progress[13],label = "BFGS")
plt.plot(x14,progress[14],label = "CG")
plt.plot(x15,progress[15],label = "Powell")       
plt.tight_layout()
plt.legend() 

plt.subplot(3,2,5)
plt.title("Exp")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x16,progress[16],label = "Nerlder-Mead")
plt.plot(x17,progress[17],label = "BFGS")
plt.plot(x18,progress[18],label = "CG")
plt.plot(x19,progress[19],label = "Powell")
plt.tight_layout()
plt.legend() 
plt.show()       

# plt.legend([line1, line2, line3], ['label1', 'label2', 'label3'])
# # The default (Nelder Mead)
# result = optimize.minimize(parabolic,x0=3, method='Nelder-Mead',options={'disp': True, 'return_all': True,})
# xf_para = result["x"]
# plt.plot(xf_para, parabolic(xf_para), "o")

# #BFGS
# result2 = optimize.minimize(parabolic, x0=3, method='BFGS', options={'disp': True, 'return_all': True, })
# xf2_para = result2["x"]
# plt.plot(xf2_para, parabolic(xf2_para), "o")
# jac_para = result2["jac"]
# plt.plot(jac_para, "o")

# #hess_para = result2["hess"]
# #plt.plot(hess_para, "o")

# #CG
# result3 = optimize.minimize(parabolic, x0=3, method='CG', jac=None, tol=0.001, options={'gtol': 1e-05, 'norm': np.inf, 'eps': 1.4901161193847656e-08, 'maxiter': None, 'disp': True, 'return_all': True, 'finite_diff_rel_step': None})
# xf3_para = result3["x"]
# plt.plot(xf3_para, parabolic(xf3_para), "o")
# jac_para2 = result3["jac"]
# plt.plot(jac_para, "o")

# #Newton-CG
# result4 = optimize.minimize(parabolic, x0 = 3,method='Newton-CG', jac= parabolic, hess=parabolic, hessp=None, tol=0.001, options={'xtol': 1e-05, 'eps': 1.4901161193847656e-08, 'maxiter': None, 'disp': True, 'return_all': True})
# xf4_para = result4["x"]
# plt.plot(xf4_para, parabolic(xf4_para), "o")
# jac_para3 = result4["jac"]
# plt.plot(jac_para3, "o")
# #hess_para3 = result4["hess"]
# #plt.plot(hess_para3, "o")
# Out:
# C:\Users\erick\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py:2642: RuntimeWarning: overflow encountered in multiply
#   elif (w - wlim)*(wlim - xc) >= 0.0:
# C:\Users\erick\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py:2646: RuntimeWarning: overflow encountered in multiply
#   elif (w - wlim)*(xc - w) > 0.0:
# C:\Users\erick\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py:2626: RuntimeWarning: overflow encountered in multiply
#   if (w - xc) * (xb - w) > 0.0:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-bb2873f2146e> in <module>
#      32 #     if (m = 'Newton-CG'):
#      33 #         J =
# ---> 34     result = optimize.minimize(f,x0 = 3, method = m, tol=1e-9,callback = callback)
#      35     xf = result["x"]
#      36     callback(xf)
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

def parabolic(x):
    return x**2 + 10

def sine(x):
    return np.sin(x)

def inverse(x):
    return 1/x

def mos(x):
    return 2**x + np.sin(x)

def exp(x):
    return x**2 + np.sin(x)

from scipy import optimize

def callback(x):
    history.append(x)
    
# The default (Nelder Mead)
optimizer_list = ['Nelder-Mead','BFGS','CG','Powell']
flist = [parabolic, sine, inverse, mos]     
progress = []
for m,f in product(optimizer_list,flist): 
    history = []
#     print(m,f)
#     if (m = 'Newton-CG'):
#         J = 
    result = optimize.minimize(f,x0 = 3, method = m, tol=1e-9,callback = callback)
    xf = result["x"]
    callback(xf)
    progress.append(history)
#     print(*progress,sep = "\n")
# print(len(progress))
# print(len(progress[0]))
# print(len(progress[1]))
# print(len(progress[2]))
# print(len(progress[3]))

x = np.arange(len(progress[0]))
x1 = np.arange(len(progress[1]))
x2 = np.arange(len(progress[2]))
x3 = np.arange(len(progress[3]))
x4 = np.arange(len(progress[4]))
x5 = np.arange(len(progress[5]))
x6 = np.arange(len(progress[6]))
x7 = np.arange(len(progress[7]))
x8 = np.arange(len(progress[8]))
x9 = np.arange(len(progress[9]))
x10 = np.arange(len(progress[10]))
x11 = np.arange(len(progress[11]))
x12 = np.arange(len(progress[12]))
x13 = np.arange(len(progress[13]))
x14 = np.arange(len(progress[14]))
x15 = np.arange(len(progress[15]))
# x16 = np.arange(len(progress[16]))
# x17 = np.arange(len(progress[17]))
# x18 = np.arange(len(progress[18]))
# x19 = np.arange(len(progress[19]))


plt.subplots_adjust(left= 0.25, right= 1.8, bottom= 0.2, top= 1.8, wspace= 1, hspace= 1)


plt.subplot(3,2,1)
plt.title("Parabolic")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x,progress[0], label = "Nerlder-Mead")
plt.plot(x1,progress[1], label = "BFGS")
plt.plot(x2,progress[2], label = "CG ")
plt.plot(x3,progress[3], label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(3,2,2)
plt.title("Sine")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x4,progress[4],label = "Nerlder-Mead")
plt.plot(x5,progress[5],label = "BFGS")
plt.plot(x6,progress[6],label = "CG")
plt.plot(x7,progress[7],label = "Powell")
plt.tight_layout() 
plt.legend() 

plt.subplot(3,2,3)
plt.title("Inverse")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x8,progress[8],label = "Nerlder-Mead")
plt.plot(x9,progress[9],label = "BFGS")
plt.plot(x10,progress[10],label = "CG")
plt.plot(x11,progress[11],label = "Powell")
plt.tight_layout()
plt.legend() 

plt.subplot(3,2,4)
plt.title("Mos")
plt.xlabel("x value at each step")
plt.ylabel("Steps")
plt.plot(x12,progress[12],label = "Nerlder-Mead")
plt.plot(x13,progress[13],label = "BFGS")
plt.plot(x14,progress[14],label = "CG")
plt.plot(x15,progress[15],label = "Powell")       
plt.tight_layout()
plt.legend() 

# plt.subplot(3,2,5)
# plt.title("Exp")
# plt.xlabel("x value at each step")
# plt.ylabel("Steps")
# plt.plot(x16,progress[16],label = "Nerlder-Mead")
# plt.plot(x17,progress[17],label = "BFGS")
# plt.plot(x18,progress[18],label = "CG")
# plt.plot(x19,progress[19],label = "Powell")
# plt.tight_layout()
# plt.legend() 
plt.show()       

# plt.legend([line1, line2, line3], ['label1', 'label2', 'label3'])
# # The default (Nelder Mead)
# result = optimize.minimize(parabolic,x0=3, method='Nelder-Mead',options={'disp': True, 'return_all': True,})
# xf_para = result["x"]
# plt.plot(xf_para, parabolic(xf_para), "o")

# #BFGS
# result2 = optimize.minimize(parabolic, x0=3, method='BFGS', options={'disp': True, 'return_all': True, })
# xf2_para = result2["x"]
# plt.plot(xf2_para, parabolic(xf2_para), "o")
# jac_para = result2["jac"]
# plt.plot(jac_para, "o")

# #hess_para = result2["hess"]
# #plt.plot(hess_para, "o")

# #CG
# result3 = optimize.minimize(parabolic, x0=3, method='CG', jac=None, tol=0.001, options={'gtol': 1e-05, 'norm': np.inf, 'eps': 1.4901161193847656e-08, 'maxiter': None, 'disp': True, 'return_all': True, 'finite_diff_rel_step': None})
# xf3_para = result3["x"]
# plt.plot(xf3_para, parabolic(xf3_para), "o")
# jac_para2 = result3["jac"]
# plt.plot(jac_para, "o")

# #Newton-CG
# result4 = optimize.minimize(parabolic, x0 = 3,method='Newton-CG', jac= parabolic, hess=parabolic, hessp=None, tol=0.001, options={'xtol': 1e-05, 'eps': 1.4901161193847656e-08, 'maxiter': None, 'disp': True, 'return_all': True})
# xf4_para = result4["x"]
# plt.plot(xf4_para, parabolic(xf4_para), "o")
# jac_para3 = result4["jac"]
# plt.plot(jac_para3, "o")
# #hess_para3 = result4["hess"]
# #plt.plot(hess_para3, "o")
# Out:
# C:\Users\erick\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py:2642: RuntimeWarning: overflow encountered in multiply
#   elif (w - wlim)*(wlim - xc) >= 0.0:
# C:\Users\erick\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py:2646: RuntimeWarning: overflow encountered in multiply
#   elif (w - wlim)*(xc - w) > 0.0:
# C:\Users\erick\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py:2626: RuntimeWarning: overflow encountered in multiply
#   if (w - xc) * (xb - w) > 0.0:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-57-617f8305e3c8> in <module>
#      32 #     if (m = 'Newton-CG'):
#      33 #         J =
# ---> 34     result = optimize.minimize(f,x0 = 3, method = m, tol=1e-9,callback = callback)
#      35     xf = result["x"]
#      36     callback(xf)
#
# ...
